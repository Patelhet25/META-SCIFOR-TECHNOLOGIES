# %%
from __future__ import division
#question2

field1 = int(input("ENTER NUMBER 1:-"))
field2 = int(input("ENTER NUMBER 2:-"))

def add():
  global addition
  addition = field1 + field2
  print("THE ADDITION OF 2 FIELDS:-", addition)
add()

def sub():
  global substrcation
  substraction = field1 - field2
  print("THE SUBSTRACTION OF 2 FIELDS:-", substraction)
sub()

def muliti():
  global multiplication
  multiplication = field1 * field2
  print("THE MULTIPLICATION OF 2 FIELDS:-", multiplication)
muliti()

def div():
  global division
  division = field1 % field2
  print("THE DIVISION OF 2 FIELDS:-", division)
div()
# Out:
# ENTER NUMBER 1:-20
# ENTER NUMBER 2:-10
# THE ADDITION OF 2 FIELDS:- 30
# THE SUBSTRACTION OF 2 FIELDS:- 10
# THE MULTIPLICATION OF 2 FIELDS:- 200
# THE DIVISION OF 2 FIELDS:- 0

# %%
# question 1

def quiz():
  question={

  }

# %%
# question 3

def odd():
  if
