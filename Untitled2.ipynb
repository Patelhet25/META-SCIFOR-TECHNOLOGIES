# %%
table = input("Enter Number:-")
for i in range(1,11):
  print(table,"x",i,"=",i*2)
# Out:
# Enter Number:-6
# 6 x 1 = 2
# 6 x 2 = 4
# 6 x 3 = 6
# 6 x 4 = 8
# 6 x 5 = 10
# 6 x 6 = 12
# 6 x 7 = 14
# 6 x 8 = 16
# 6 x 9 = 18
# 6 x 10 = 20

# %%
name = input("EnterName:-")
for p in name:
  print(p)
# Out:
# EnterName:-ram
# r
# a
# m

# %%
a = input("Enter Value")
for i in range(1,11):
  if i == 1:
    print(a*2)
  else:
      pass
  print(a)
# Out:
# Enter Value*
# **
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
min
