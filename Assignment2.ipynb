# %%
# Program-1

chocolates = 327
student = 78
print("TOTAL NUMBER OF CHOCOLATE LEFT:-", chocolates%student)
# Out:
# TOTAL NUMBER OF CHOCOLATE LEFT:- 15

# %%
# Program-2

name = input("Enter Your Name:-")
mobileno = input("Enter Your Mobile No:-")
age = input("Enter Your Age:-")
emailid = input("Enter Your Email Id:-")
print("Hi",name,"!! Thanks for visiting our restaurant and registering for our lucky draw competition on our 25th Anniversary.,""Once the lucky draw results are announced you will receive a message on your mobile number :",mobileno,"An detailed description of your gift on your email Id :",emailid,"Thank you for being a valued customer",name,"!!""Dominos")
# Out:
# Enter Your Name:-Het
# Enter Your Mobile No:-9624836373
# Enter Your Age:-26
# Enter Your Email Id:-patel.het25@yahoo.com
# Hi Het !! Thanks for visiting our restaurant and registering for our lucky draw competition on our 25th Anniversary.Once the lucky draw results are announced you will receive a message on your mobile number : 9624836373 An detailed description of your gift on your email Id : patel.het25@yahoo.com Thank you for being a valued customer Het !!Dominos

# %%
# Program-3

student = 60
team = 4
print("TOTAL NUMBER OF GROUP:-", student//team)
# Out:
# TOTAL NUMBER OF GROUP:- 15

# %%
# Program-4

fehrenheit = int(input("Enter Fehreneheit:-"))
cel = (fehrenheit - 32) * 5/9
print("Converted Fehrenheit to Celsius:-", cel)
# Out:
# Enter Fehreneheit:-100
# Converted Fehrenheit to Celsius:- 37.77777777777778
