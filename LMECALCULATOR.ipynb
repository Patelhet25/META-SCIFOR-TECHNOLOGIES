# %%
LME = int(input("ENTER THE CURRENT LME:-"))
premium = 190
total_of_premium = LME + premium
print("TOTAL OF LME+PREMIUM:-",total_of_premium)
dollar = float(input("ENTER THE CURRENT RBI DOLLAR RATE:-"))
multiply_1 = total_of_premium * dollar
print("MUlTI OF DOLLAR+LMEPREMIUM:-",multiply_1)
multiply_factor = 1.050
multiply_2 = multiply_1 * multiply_factor
print("MULTI OF DOLLAR+MULTIPLY FACTOR:-",multiply_2)
divide = multiply_2 / 1000
print("DIVIDE BY TONE:-",divide)
transport = 5
adiition = divide + transport
print("ADDITION OF TRANSPORTATION:-",adiition)
fabrication = 41
total_price = adiition + fabrication
print("TOTAL PRICE OF COPPER:-",total_price)
# Out:
# ENTER THE CURRENT LME:-9320
# TOTAL OF LME+PREMIUM:- 9510
# ENTER THE CURRENT RBI DOLLAR RATE:-84
# MUlTI OF DOLLAR+LMEPREMIUM:- 798840.0
# MULTI OF DOLLAR+MULTIPLY FACTOR:- 838782.0
# DIVIDE BY TONE:- 838.782
# ADDITION OF TRANSPORTATION:- 843.782
# TOTAL PRICE OF COPPER:- 884.782

# %%
LME = int(input("ENTER THE CURRENT LME:-"))
premium = 190
total_of_premium = LME + premium
print("TOTAL OF LME+PREMIUM:-",total_of_premium)
dollar = float(input("ENTER THE CURRENT RBI DOLLAR RATE:-"))
multiply_1 = total_of_premium * dollar
print("MUlTI OF DOLLAR+LMEPREMIUM:-",multiply_1)
multiply_factor = 1.150
multiply_2 = multiply_1 * multiply_factor
print("MULTI OF DOLLAR+MULTIPLY FACTOR:-",multiply_2)
divide = multiply_2 / 1000
print("DIVIDE BY TONE:-",divide)
transport = 5
adiition = divide + transport
print("ADDITION OF TRANSPORTATION:-",adiition)
fabrication = 41
total_price = adiition + fabrication
print("TOTAL PRICE OF COPPER:-",total_price)
# Out:
# ENTER THE CURRENT LME:-9300
# TOTAL OF LME+PREMIUM:- 9490
# ENTER THE CURRENT RBI DOLLAR RATE:-84
# MUlTI OF DOLLAR+LMEPREMIUM:- 797160.0
# MULTI OF DOLLAR+MULTIPLY FACTOR:- 916733.9999999999
# DIVIDE BY TONE:- 916.7339999999999
# ADDITION OF TRANSPORTATION:- 921.7339999999999
# TOTAL PRICE OF COPPER:- 962.7339999999999
