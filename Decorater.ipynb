# %%
def cal(add):
  def inp():
    print("THIS IS FIRST")
    add()
    print("THIS IS SECOND")
  return inp

@cal
def result():
  print("HELLO")

result()
# Out:
# THIS IS FIRST
# HELLO
# THIS IS SECOND

# %%
def calculator(multi):
  def value():
    z = a * b
    print(z)
    multi()
    c = a*100*b
    print(c)
    return value

a = int(input("ENTER NUMBER1:-"))
b = int(input("ENETR NUMBER2:-"))

@calculator
def midd():
  print("this")

midd()
# Out:
# ENTER NUMBER1:-10
# ENETR NUMBER2:-10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c9e9c8752937> in <cell line: 17>()
#      15   print("this")
#      16
# ---> 17 midd(calculator)
#
# TypeError: 'NoneType' object is not callable

# %%
def third(sub):
  def multi():
    return total
    sub()
    return total_2

marks = int(input("ENTER TOTAL MARKS:"))
divide = 700
total = marks * 700 / 100

@third
def perfecntage():
  print("TOTAL PERCENTAGE")

perfecntage(total)
# Out:
# ENTER TOTAL MARKS:699
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-923fd990f51e> in <cell line: 15>()
#      13   print("TOTAL PERCENTAGE")
#      14
# ---> 15 perfecntage()
#
# TypeError: 'NoneType' object is not callable
