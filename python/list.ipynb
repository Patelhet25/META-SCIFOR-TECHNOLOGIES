# %%
name = ["ram","shyam","raju"]
print(name)
name.append("HET")
print(name)
name.copy()
print(name)
name.clear()
print(name)
names = ["ram","shyam","raju"]
name.reverse()
print(names)
names.pop(2)
print(names)
# Out:
# ['ram', 'shyam', 'raju']
# ['ram', 'shyam', 'raju', 'HET']
# ['ram', 'shyam', 'raju', 'HET']
# []
# ['ram', 'shyam', 'raju']
# ['ram', 'shyam']
