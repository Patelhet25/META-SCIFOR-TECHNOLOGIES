# %%
''''Yash now learned how he could use inheritance to create a square class
with the help of the existing rectangle class. Now with the help of method
overriding, he wants to change the side of the squares as well. He just
need to redefine the method setLength( ) and setBreadth( ).''''

# %%
class rectangle:
  def __init__(self,lenth,breadth):
    self.lenth = lenth
    self.breath = breath
  def measure(self):
    return self.lenth * self.breath
class square(rectangle):
  def __init__(self,corner):
    self.corner = corner
  def setlenth(self):
    return self.lenth
    return self.breath
  def setbreath(self):
    return self.lenth
    return self.breath
  def measure(self):
    return self.lenth * self.breath
lenth = int(input("ENTER LENTH:-"))
breath = int(input("ENTER BREATH:-"))

rectangle_1 = rectangle(lenth,breath)
rectangle_1.measure()
# Out:
# ENTER LENTH:-40
# ENTER BREATH:-80
# 3200

# %%
''''TASK2- Vehicle Problem:
In a town, a garage owner manages cars and motorcycles. The owner
needs a program to track vehicle operations. Cars honk when started;
motorcycles pop wheelies when started. The owner wants to start and
stop vehicles as requested. Instructions for the code: Create a Python
program with classes for Vehicle, Car, and Motorcycle as shown. Define
attributes and methods for starting and stopping vehicles. Create
instances of Car and Motorcycle. Demonstrate starting, performing
vehicle-specific actions, and stopping both instances. Ensure the
program runs without errors and showcases vehicle functionalities.''''

# %%
class Vehicle:
  def __init__(self,car,motorcycle,number):
    self.car = car
    self.motocycle = motorcycle
    self.number = number
class car(Vehicle):
  def car_honk(self):
    print("CAR HONK AND IT STARTED")
class motorcycle(Vehicle):
  def motorcyle_Pop(self):
    print("MOTOT CYCLES POP WHEELIES")
print("1.CAR")
print("2.MOTORCYCLE")
number = int(input("ENTER NUMBER 1 AND 2:-"))
car_1 = car(car,motorcycle,number)
car_1.car_honk()
motorcycle_1 = motorcycle(car,motorcycle,number)
motorcycle_1.motorcyle_Pop()
# Out:
# 1.CAR
# 2.MOTORCYCLE
# ENTER NUMBER 1 AND 2:-1
# CAR HONK AND IT STARTED
# MOTOT CYCLES POP WHEELIES
