# %%
pip install numpy

# %%
import pandas as pd

data = pd.read_csv("/content/NASA_Facilities.csv")
data
# Out:
#                                Center Center Search Status  \
# 0                Stennis Space Center               Public
# 1                Ames Research Center               Public
# 2         Goddard Space Flight Center               Public
# 3               Glenn Research Center               Public
# 4        Marshall Space Flight Center               Public
# ..                                ...                  ...
# 480              Kennedy Space Center               Public
# 481      Wallops Flight Facility/GSFC               Public
# 482              Kennedy Space Center               Public
# 483           Langley Research Center               Public
# 484  Armstrong Flight Research Center               Public
#
#                                               Facility  FacilityURL  \
# 0                                 Test Stand A-2 #4122          NaN
# 1    N229 - EXPER. AEROTHERMODYNAMIC FAC.: ELECTRIC...          NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Center                485 non-null    object
#  1   Center Search Status  485 non-null    object
#  2   Facility              485 non-null    object
#  3   FacilityURL           0 non-null      float64
#  4   Occupied              393 non-null    object
#  5   Status                399 non-null    object
#  6   URL Link              145 non-null    object
#  7   Record Date           485 non-null    object
#  8   Last Update           479 non-null    object
#  9   Country               485 non-null    object
#  10  Location              485 non-null    object
#  11  City                  485 non-null    object
#  12  State                 485 non-null    object
#  13  Zipcode               485 non-null    object
# dtypes: float64(1), object(13)
# memory usage: 53.2+ KB

# %%
data.columns
# Out:
# Index(['Center', 'Center Search Status', 'Facility', 'FacilityURL', 'Occupied',
#        'Status', 'URL Link', 'Record Date', 'Last Update', 'Country',
#        'Location', 'City', 'State', 'Zipcode'],
#       dtype='object')

# %%
data.shape
# Out:
# (485, 14)

# %%
data.isnull().sum()
# Out:
# Center                    0
# Center Search Status      0
# Facility                  0
# FacilityURL             485
# Occupied                 92
# Status                   86
# URL Link                340
# Record Date               0
# Last Update               6
# Country                   0
# Location                  0
# City                      0
# State                     0
# Zipcode                   0
# dtype: int64

# %%
data['Location']
# Out:
#        FacilityURL
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
data.describe()
# Out:
#        FacilityURL
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['FacilityURL'].plot(kind='hist', bins=20, title='FacilityURL')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['FacilityURL'].plot(kind='line', figsize=(8, 4), title='FacilityURL')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data.head(3)
# Out:
#                         Center Center Search Status  \
# 0         Stennis Space Center               Public
# 1         Ames Research Center               Public
# 2  Goddard Space Flight Center               Public
#
#                                             Facility  FacilityURL  \
# 0                               Test Stand A-2 #4122          NaN
# 1  N229 - EXPER. AEROTHERMODYNAMIC FAC.: ELECTRIC...          NaN
# 2                       500 WSC: Antenna, 10m S-band          NaN
#
#                  Occupied    Status                            URL Link  \
# 0  01/01/1964 12:00:00 AM  Inactive          http://rockettest.nasa.gov
# 1  01/01/1961 12:00:00 AM    Active  http://thermo-physics.arc.nasa.gov
# 2  01/01/1977 12:00:00 AM    Active                                 NaN
#
#               Record Date             Last Update Country  \
# 0  03/01/1996 12:00:00 AM  04/06/2015 12:00:00 AM      US
# 1  03/01/1996 12:00:00 AM  06/13/2014 12:00:00 AM      US
# ...

# %%
data_1.dropna(inplace=True)

# %%
# mam i have use match result csv instead of nasa file because it does not have that data
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5], hist=False)
data_1 = pd.read_csv("/content/Match_Results.csv")
home = data_1.home_score.head()
away = data_1.away_score.head()
plt.title("MATCH RESULT")
plt.xlabel("HOME")
plt.ylabel("AWAY")
plt.plot(home,away,color="blue")
plt.legend()
plt.show()
# Out:
# <ipython-input-11-7c374572048b>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
homw_1= data_1['home_score'].mean()
data_1.fillna(homw_1)
# Out:
#              date    home_team away_team  home_score  away_score  \
# 0      1872-11-30     Scotland   England           0           0
# 1      1873-03-08      England  Scotland           4           2
# 2      1874-03-07     Scotland   England           2           1
# 3      1875-03-06      England  Scotland           2           2
# 4      1876-03-04     Scotland   England           3           0
# ...           ...          ...       ...         ...         ...
# 47394  2024-07-10  Netherlands   England           1           2
# 47395  2024-07-10      Uruguay  Colombia           0           1
# 47396  2024-07-13       Canada   Uruguay           2           2
# 47397  2024-07-14        Spain   England           2           1
# 47398  2024-07-14    Argentina  Colombia           1           0
#
#          tournament           city        country  neutral
# 0          Friendly        Glasgow       Scotland    False
# 1          Friendly         London        England    False
# ...

# %%
# mam i have use match result csv instead of nasa file because it does not have that data

import matplotlib.pyplot as plt
import pandas as pd
home = list(data_1.home_score())
away = list(data_1.away_score())
fig = plt.figure(figsize = (10, 5))
plt.bar(home,away, color ='blue',width = 0.4)
plt.xlabel("home")
plt.ylabel("away")
plt.title("SCORE")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-45fe48ed82af> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4 import pandas as pd
# ----> 5 home = list(data_1.home_score())
#       6 away = list(data_1.away_score())
#       7 fig = plt.figure(figsize = (10, 5))
#
# TypeError: 'Series' object is not callable
