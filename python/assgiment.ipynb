# %%
print("Het Patel")
print(25)
# Out:
# Het Patel
# 25

# %%
print("| ")
print("- ")
print("/ ")
print("\ ")
# Out:
# |
# -
# /
# \

# %%
print("Het\nRaj\nKevin\nPriyank\nDeep")
# Out:
# Het
# Raj
# Kevin
# Priyank
# Deep

# %%
name = input("Enter Name:-")
age = (input("Enter Age:-"))
city = input("Enter city:-")
state = input("Enter state:-")
contact  = (input("Enter Contact no:-"))
print("My Name is " + name)
print("My age is " + age)
print("My City is " + city)
print("My State is " + state)
print("My Contact is " + contact)
# Out:
# Enter Name:-Het patel
# Enter Age:-26
# Enter address:-ahmedabad
# Enter state:-guj
# Enter Contact no:-0000000000
# My Name is Het patel
# My age is 26
# My City is ahmedabad
# My State is guj
# My Contact is0000000000

# %%
a = ("Hi, I am a chatbot. What is your name?")
print(a)
b = input("What Is Your name ")
print("Oh " + b + " in which grade you are right now?")
c = input("Enter your grade ")
print(b + " you are in " + c +" grade " )
d = (" Can I ask you one question? yes or no?")
print(d)
print("Yes")
e = (input("Enter Number1:-"))
f = (input("Enter Number2:-"))
g = ("Tell me " + e + "+" + f)
print(g)
total = int(e)+int(f)
print(total)
h = ("Good! Your answer is correct. Bye")
print(h)
print("byee")
# Out:
# Hi, I am a chatbot. What is your name?
# What Is Your name Het
# Oh Het in which grade you are right now?
# Enter your grade 10
# Het you are in 10 grade
#  Can I ask you one question? yes or no?
# Yes
# Enter Number1:-20
# Enter Number2:-20
# Tell me 20+20
# 40
# Good! Your answer is correct. Bye
# byee

# %%
book = int(input("Enter Number Of Books:-"))
print("Your Total Amount Is:-", book * 2)
# Out:
# Enter Number Of Books:-20
# Your Total Amount Is:- 40

# %%
currentyear = 2024
studentage = int(input("Enter Born Year:-"))
age = int(currentyear)-int(studentage)
print("Your Current Age Is:-",age)
# Out:
# Enter Born Year:-1998
# Your Current Age Is:- 26

# %%
chocolates = 327
student = 78
print("TOTAL NUMBER OF CHOCOLATE LEFT IS:-", chocolates%student)
# Out:
# TOTAL NUMBER OF CHOCOLATE LEFT IS:- 15

# %%
name = input("Enter Your Name:-")
mobileno = input("Enter Your Mobile No:-")
age = input("Enter Your Age:-")
emailid = input("Enter Your Email Id:-")
print("Hi",name,"!! Thanks for visiting our restaurant and registering for our lucky draw competition on our 25th Anniversary.""Once the lucky draw results are announced you will receive a message on your mobile number :",mobileno,"An detailed description of your gift on your email Id :",emailid,"Thank you for being a valued customer",name,"!!""Dominos")
# Out:
# Enter Your Name:-Het
# Enter Your Mobile No:-9624836373
# Enter Your Age:-26
# Enter Your Email Id:-xyz@gmail.com
# Hi Het !! Thanks for visiting our restaurant and registering for our lucky draw competition on our 25th Anniversary.Once the lucky draw results are announced you will receive a message on your mobile number : 9624836373 An detailed description of your gift on your email Id : xyz@gmail.com Thank you for being a valued customer Het !!Dominos

# %%
student = 60
team = 4
print("TOTAL NUMBER OF GROUP:-", student//team)
# Out:
# TOTAL NUMBER OF GROUP:- 15

# %%
# Out:
# Enter Fehreneheit:-120
# 89
