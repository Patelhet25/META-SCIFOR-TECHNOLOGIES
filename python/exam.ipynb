# %%
#The RTO (Regional Transport Office) website holds a registration form which is responsible for registering a user for a Driving License.
#The RTO wants to take the next step if and only if the user's age is greater than or equal to 18.

#Scenario 1 : When Traffic Light is Red

#Jake, a 20 year old teenager has learnt to ride a bike and is a bit confused with the traffic signals.
 #He doesn't know what to do when the signal is red.

#So In this scenario Jake should just know what Jake should do when the signal is red whether he should leave or stop.

#So Write a If-Else condition to guide Jake

# %%
name = input("Enter Name Of Applicant:- ")
dob = 2024
bornyear = int(input("Enter bornyear:- "))
contact = input("Enter ContactNO:- ")
age1 = (dob-bornyear)
print("Current age is:- ", age1)

if age1 >= 18:
  print("Your are Eligible For Driving License")
else:
  print("Sorry!!!Your are Not Eligible For Driving License")
# Out:
# Enter Name Of Applicant:- Het Patel
# Enter bornyear:- 2009
# Enter ContactNO:- 0000000000
# Current age is:-  15
# Sorry!!!Your are Not Eligible For Driving License

# %%
name = ("Jake")
x = input("Enter Colour:- ")
if x=="red":
  print("you have to stop", name)
elif x=="green":
  print("you have to leave", name)
elif x=="orange":
  print("you have to slow down", name)
else:
  print("None")
# Out:
# Enter Colour:- blue
# None

# %%
"""Mary, a 15 year old girl, was watching her mom making a budget list every month,
either her mom use to forget few things or she use to go out of budget due to no proper grocery list that says quantity of items, prices and stuff.

So Mary wants to help her mom in managing the monthly groceries by creating an app that takes grocery item name,
 item price and quantity of item.

Before all this, the app is suppose to accept the budget amount,
 if shopping list items price cross over the budget amount then any new items should not be added to the list.

There should be 2 things in the menu of the app one to add an item and the second option to exit from the menu once the add item is chosen,
then the item name,item quantity and item price should be accepted and the price should be checked with the budget amount.
If the item amount is crossing the budget amount then the item cannot be added to the list.

If the exit option is chosen then the total budget amount and the"""

# %%
budget = 2000
print("Select option:- ")
print("1.Add item")
print("2.exit")
option = input("Enter Option:- ")
if option=="1":
  print("Add Item")
  name = input("Enter Item Name:-")
  quantity = int(input("Enter Number Of Quantity:-"))
  price = int(input("Enter Price:-"))
  total = (quantity**price)
  print(total)
elif total <= budget:
  print("Item will Not be Add in List")
elif total >= budget:
  print("Item will Not be Add in List")
elif option=="2":
  print("You are exit from App")
else:
  print("Wrong Selected")
# Out:
# Select option:-
# 1.Add item
# 2.exit
# Enter Option:- 1
# Add Item
# Enter Item Name:-sugar
# Enter Number Of Quantity:-50
# Enter Price:-5000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-790930166a50> in <cell line: 6>()
#      10   price = int(input("Enter Price:-"))
#      11   total = (quantity**price)
# ---> 12   print(total)
#      13 elif total <= budget:
#      14   print("Item will Not be Add in List")
#
# ValueError: Exceeds the limit (4300) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

# %%
"""Sameer, a resident of India met John, a resident of california on facebook and they became friends,
just in a conversation they planned to know each other's height and there was a problem, John would understand only if told in centimeter(cm) format.
So write a program to help John to understand Sameer’s height in python to convert Feet & Inches To CM"""
# Out:
# "Sameer, a resident of India met John, a resident of california on facebook and they became friends, \njust in a conversation they planned to know each other's height and there was a problem, John would understand only if told in centimeter(cm) format.\nSo write a program to help John to understand Sameer’s height in python to convert Feet & Inches To CM"

# %%
feet = int(input("Enter feet:-"))
inches = feet * 12
print(inches)
# Out:
# Enter feet20
# 240
