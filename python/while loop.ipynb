# %%
number = int(input("Enter Number:- "))
start = 1
while start <= 10:
  answer = start * number
  print(start,"*", number, "=", answer)
  start += 1
# Out:
# Enter Number:- 8
# 1 * 8 = 8
# 2 * 8 = 16
# 3 * 8 = 24
# 4 * 8 = 32
# 5 * 8 = 40
# 6 * 8 = 48
# 7 * 8 = 56
# 8 * 8 = 64
# 9 * 8 = 72
# 10 * 8 = 80
