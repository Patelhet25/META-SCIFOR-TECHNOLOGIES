# %%
def get_smallest_odd(numlist):
  oddcount = 0
  smallest = float('inf')
  for num in numlist:
    if (num % 2) != 0:
      oddcount += 1
      if num < smallest:
        # INSERT MISSING CODE
    return oddcount, smallest
# Out:
#   File "<ipython-input-1-2970fb003359>", line 9
#     return oddcount, smallest
#     ^
# IndentationError: expected an indented block after 'if' statement on line 7
