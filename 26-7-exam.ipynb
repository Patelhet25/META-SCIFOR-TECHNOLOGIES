# %%
'''Create a student management system project using the classes and objects concept in python which should perform the following operations

1.Accept Student details

2.Display Student Details

3.Search Details of a Student

4.Delete Details of Student

5.Update Student Details

6.Exit'''

#create a student class and add functions for the above shown options in the description and ask the user to choose one among them
# Out:
# 'Create a student management system project using the classes and objects concept in python which should perform the following operations\n\n1.Accept Student details\n\n2.Display Student Details\n\n3.Search Details of a Student\n\n4.Delete Details of Student\n\n5.Update Student\xa0Details\n\n6.Exit'

# %%
class student:
  print(1,"Accept Student details")
  print(2,"display Student details")
  print(3,"search Student details")
  print(4,"delete Student details")
  print(5,"update Student details")
  print(6,"EXIT")
  select = int(input("ENTER YOUR NUMBER:-"))

  def __init__(self,name,number,dob,email):
    self.name = name
    self.number = number
    self.dob = dob
    self.email = email

  if select == 1:
    print("ADD YOUR DATA")
    def accept(self):
      return self.name,self.number,self.dob,self.email
  elif select == 2:
    print("DISPLAY THE DATA")
    def display(self):
      return self.display.accept(name,number,dob,email)
  elif select == 3:
    print("ENTER THE NUMBER")
    number2 = input("ENTER NUMBER")
    def search(self):
      return self.search.number(name,dob,email)
  elif select == 4:
    print("DELETE THE DATA")
    def delete(self):
      return self.delete.accept(name,number,dob,email)
  elif select == 5:
    def update(self):
      return self.update(name,number,dob,email)
  elif select == 6:
    print("EXIT")
  else:
    print("WRONG NUMBER")

name = input("ENTER YOUR NAME:-")
number = int(input("ENTER YOUR CONTACTNO:-"))
dob = input("ENTER YOUR DOB:-")
email = input("ENTER YOUR EMAILID:-")

addition = student(name,number,dob,email)
print("YOUR DATA ADDED SUCCESSFLLY:-",addition.accept())
dis = student(name,number,dob,email)
dis.display()
sear = student(name,number,dob,email)
sear.display()
dele = student(name,number,dob,email)
dele.delete()
upda = student(name,number,dob,email)
upda.update()
# Out:
# 1 Accept Student details
# 2 display Student details
# 3 search Student details
# 4 delete Student details
# 5 update Student details
# 6 EXIT
# ENTER YOUR NUMBER:-1
# ADD YOUR DATA
# ENTER YOUR NAME:-RAM
# ENTER YOUR CONTACTNO:-00000000
# ENTER YOUR DOB:-000000
# ENTER YOUR EMAILID:-adbjhvasdh@gmail.com
# YOUR DATA ADDED SUCCESSFLLY:- ('RAM ', 0, '000000', 'adbjhvasdh@gmail.com')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-6a7f44ec2932> in <cell line: 49>()
#      47 print("YOUR DATA ADDED SUCCESSFLLY:-",addition.accept())
#      48 dis = student(name,number,dob,email)
# ---> 49 dis.display()
#      50 sear = student(name,number,dob,email)
#      51 sear.display()
#
# AttributeError: 'student' object has no attribute 'display'

# %%
'''Nidhi is trying to understand how the phone gets updated with
new features with all the old features already available in the new phone.
Write a program to explain this with the help of inheritance and method
overriding. Hint: Create class Nokia1, then create class Nokia2 and
inherit all the methods from Nokia1 to Nokia2. Also, modify the required
methods in Nokia2 and add a few additional methods as well. In the
same way, you can create Nokia3 and Nokia4 as well.'''

# %%
class Nokia1:
  def __init__(self,old,old1):
    self.old = old
    self.old1 = old1

old ="this is my old features in phone"
old1 = "this is my old features 2 in phone"

class Nokia2(Nokia1):

  def new_features(self):
    return self.old,self.old1
  def modifiy(self,new,new1):
    self.new = new
    self.new1 = new1
new="THIS IS MY LATEST FEATURES AND MODIFY"
new1="THIS IS MY LATEST FEATURES"

class Nokia3(Nokia2):

  def latest(self,new,new1):
      print(self.new)
      print(self.new1)

class Nokia4(Nokia3):

  def nokia_4(self):
    print("THIS IS LATEST FEATURES")

nokia_2 = Nokia2(old,old1)
nokia_2.new_features()
nokia_3 = Nokia3(new,new1)
nokia_3.latest()
nokia_4 = Nokia4()
nokia_4.nokia()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-f0f9bc0ae9af> in <cell line: 34>()
#      32 nokia_2.new_features()
#      33 nokia_3 = Nokia3(new,new1)
# ---> 34 nokia_3.latest()
#      35 nokia_4 = Nokia4()
#      36 nokia_4.nokia()
#
# TypeError: Nokia3.latest() missing 2 required positional arguments: 'new' and 'new1'
